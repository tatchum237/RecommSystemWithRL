# %%
import pandas as pd
import numpy as np
from utils import load_data, search_duck_selenium

# Load and preprocess data
data = load_data("data/songs.csv")



def fill_missing_links(songs_links, data):
    # Find rows where 'link' is missing or an empty string
    missing_links = songs_links['link'].isna() | (songs_links['link'] == '')

    if not any(missing_links):
        print("No missing links to fill.")
        return songs_links

    # Iterate over rows with missing links
    for index in songs_links[missing_links].index:
        title = songs_links.loc[index, 'Title']
        year_column = pd.DataFrame(data[['(1980s)', '(1990s)', '(2000s)', '(2010s)', '(2020s)']]).eq(1, axis=0).idxmax(axis=1)[index]
        query = f"song called: {title} {year_column} inurl:youtube -lyrics"

        try:
            link = search_duck_selenium(query)
        except Exception as e:
            print(f"Error searching YouTube for '{title}': {str(e)}")
            continue

        # Update the link in the 'songs_links' DataFrame
        songs_links.loc[index, 'link'] = link
        print(f"Link for '{title}' updated.")

    return songs_links

# %%
songs_links = pd.read_csv("data/songs_links.csv")
songs_links = fill_missing_links(songs_links, data)
# Out:
# Link for 'A Sky Full of Stars' updated.
# Link for 'Back in Black' updated.
# Link for 'Dream On' updated.
# Link for 'Teardrop' updated.
# Link for 'Sorry' updated.
# Link for 'Paradise City' updated.
# Link for 'Paranoid' updated.
# Link for 'Someone Like You' updated.
# Link for 'Us and Them' updated.
# Error: list index out of range
# Link for 'Iris' updated.
# Link for 'Black Hole Sun' updated.
# Link for 'HUMBLE.' updated.
# Link for 'Eye of the Tiger' updated.
# Link for 'The Pretender' updated.
# Link for 'Faint' updated.
# Link for 'Breaking the Habit' updated.
# Link for 'Sugar (feat. Francesco Yates)' updated.
# Error: list index out of range
# Link for 'Treat You Better' updated.
# Link for 'Let It Happen' updated.
# Link for 'Thunder' updated.
# Link for 'Believer' updated.
# Link for 'Trouble' updated.
# Link for 'Coming Back to Life' updated.
# Link for 'All of Me' updated.
# Link for 'Gimme Shelter' updated.
# Link for 'Here Without You' updated.
# Link for 'Beautiful Day' updated.
# Link for 'Africa' updated.
# Link for 'Work' updated.
# Link for 'The Sound of Muzak' updated.
# Link for 'Lonely Boy' updated.
# Link for 'Titanium (feat. Sia)' updated.
# Link for 'Animals' updated.
# Link for 'Sunset Lover' updated.
# Link for 'Everything in Its Right Place' updated.
# Link for 'Paint It Black' updated.
# Link for 'Toxicity' updated.
# Link for 'Home' updated.
# Link for 'The A Team' updated.
# Link for 'One More Time' updated.
# Link for 'Points of Authority' updated.
# Link for 'The Greatest' updated.
# Link for 'Georgia' updated.
# Link for 'Hey There Delilah' updated.
# Link for 'Elastic Heart' updated.
# Error: list index out of range
# Link for 'What You Know' updated.
# Link for 'Have a Cigar' updated.
# Link for 'Into You' updated.
# Link for 'On the Run' updated.
# Link for 'Shiver' updated.
# Error: list index out of range
# Link for 'King Kunta' updated.
# Link for 'Burn It Down' updated.
# Link for 'Brown Eyed Girl' updated.
# Link for 'Firestone' updated.
# Link for 'When We Were Young' updated.
# Link for 'Crazy' updated.
# Link for 'Marooned' updated.
# Link for 'Waiting For Love' updated.
# Link for 'Trap Queen' updated.
# Link for 'Fast Car - Radio Edit' updated.
# Link for 'Giorgio by Moroder' updated.
# Link for 'Tom Sawyer' updated.
# Link for 'Skyfall' updated.
# Link for 'Should Have Known Better' updated.
# Link for 'Fun (feat. Tove Lo)' updated.
# Link for 'Cirrus' updated.
# Link for 'Ful Stop' updated.
# Link for 'Drag Me Down' updated.
# Link for 'Runaway' updated.
# Link for 'Middle' updated.
# Link for 'Too Good' updated.
# Link for 'Dancing Queen' updated.
# Error: list index out of range
# Link for 'Cheerleader - Felix Jaehn Remix Radio Edit' updated.
# Link for 'Don't Wanna Know' updated.
# Link for 'God Put a Smile Upon Your Face' updated.
# Link for 'Born to Die' updated.
# Link for 'I Hate U, I Love U (feat. Olivia O'Brien)' updated.
# Error: list index out of range
# Link for 'Shallow' updated.
# Link for 'Mountains' updated.
# Link for 'Good for You' updated.
# Link for 'Hide Away' updated.
# Link for 'L.A. Woman' updated.
# Link for 'Between the Bars' updated.
# Link for 'All I Need' updated.
# Error: list index out of range
# Link for 'Hands to Myself' updated.
# Link for 'Yellow Ledbetter' updated.
# Link for 'Hooked on a Feeling' updated.
# Link for 'So Long, Lonesome' updated.
# Link for 'What Lovers Do (feat. SZA)' updated.
# Link for 'Cochise' updated.
# Link for 'In The Night' updated.
# Link for 'Spies' updated.
# Link for 'Video Games' updated.
# Link for 'White Winter Hymnal' updated.
# Link for 'Green Eyes' updated.
# Link for 'Am I Wrong' updated.
# Link for 'I Wanna Be Yours' updated.
# Link for 'Communication Breakdown' updated.
# Link for 'Mr. Blue Sky' updated.
# Link for 'In Da Club' updated.
# Link for 'Tiny Dancer' updated.
# Link for 'My Hero' updated.
# Link for 'Paradise Circus' updated.
# Error: list index out of range
# Link for 'Lights' updated.
# Link for 'Banana Pancakes' updated.
# Link for 'In Bloom' updated.
# Link for 'Hard Sun' updated.
# Link for 'Electric Love' updated.
# Error: list index out of range
# Link for 'Fight Song' updated.
# Error: list index out of range
# Link for 'Nothing Arrived - Live from Spotify London' updated.
# Link for 'We Are the Champions' updated.
# Link for 'Walk' updated.
# Error: list index out of range
# Link for 'Dust in the Wind' updated.
# Error: list index out of range
# Link for 'You Can't Always Get What You Want' updated.
# Link for 'Starboy (feat. Daft Punk)' updated.
# Error: list index out of range
# Link for 'Marvin Gaye (feat. Meghan Trainor)' updated.
# Link for 'The National Anthem' updated.
# Link for 'New Divide' updated.
# Link for '"Heroes"' updated.
# Link for 'Over the Hills and Far Away' updated.
# Error: list index out of range
# Link for 'Around the World' updated.
# Link for 'A Day in the Life' updated.
# Link for 'Hysteria' updated.
# Link for 'Stan' updated.
# Link for 'Spirits' updated.
# Link for 'B.Y.O.B.' updated.
# Link for 'SexyBack' updated.
# Link for 'Your Song' updated.
# Link for 'I Can Almost See You' updated.
# Link for 'Cowboys from Hell' updated.
# Error: list index out of range
# Link for 'When I Was Your Man' updated.
# Link for 'Hit the Floor' updated.
# Link for 'O' updated.
# Link for 'Cecilia' updated.
# Link for 'Can't Help Falling in Love' updated.
# Link for 'Hardwired' updated.
# Link for 'Superstition' updated.
# Link for 'Nothing's Gonna Hurt You Baby' updated.
# Link for 'Aquarium' updated.
# Link for 'Good Life' updated.
# Error: list index out of range
# Link for 'Pink Moon' updated.
# Link for 'Aqualung' updated.
# Link for 'Habits (Stay High)' updated.
# Link for 'How Long' updated.
# Link for 'God's Plan' updated.
# Link for 'Þú ert jörðin' updated.

# %%
# Second round of missing links retrieval
# This could be done recursively till 'missing_links' is empty or directly as retries in an exception handler 
# but the manual approach leaves more room for an appropriate cooldown in the case of a soft ban
songs_links = fill_missing_links(songs_links, data)
# Out:
# Link for 'Iris' updated.
# Link for 'Treat You Better' updated.
# Link for 'What You Know' updated.
# Link for 'King Kunta' updated.
# Link for 'Cheerleader - Felix Jaehn Remix Radio Edit' updated.
# Link for 'Shallow' updated.
# Link for 'Hands to Myself' updated.
# Link for 'Lights' updated.
# Link for 'Fight Song' updated.
# Link for 'Nothing Arrived - Live from Spotify London' updated.
# Link for 'Dust in the Wind' updated.
# Link for 'You Can't Always Get What You Want' updated.
# Link for 'Marvin Gaye (feat. Meghan Trainor)' updated.
# Link for 'Around the World' updated.
# Error: list index out of range
# Link for 'When I Was Your Man' updated.
# Link for 'Pink Moon' updated.

# %%
songs_links = fill_missing_links(songs_links, data)
# Out:
# Link for 'When I Was Your Man' updated.

# %%
songs_links.to_csv("data/songs_links.csv", index=False)

# %%
songs_links = pd.read_csv('data/songs_links.csv')

# %%
# We delete links that aren't from youtube.com (8 links) and search manually
non_yt_links_idx = songs_links.loc[~songs_links['link'].str.contains('youtube.com', na = False)].index
songs_links.loc[non_yt_links_idx, 'link'] = np.nan

# %%
songs_links.to_csv("data/songs_links.csv", index=False)

# %% [markdown]
# The resulting csv file can now be edited manually
